# %%
#G Eisenstein Series truncated to N places, d: the number of derivatives, k: weight of QMF
def Gfunct(k,N,d):
    var('q')
    s=0
    if d==0:
        if k==1:
            for i in range(1,N+1):
                s+=q^i
        else:
            for i in range(1,N+1):
                s+=sigma(i,k-1)*q^i
        return -1*bernoulli(k)/(2*k)+s
    else:
        if k==1:
            for i in range(1,N+1):
                s+=i^d*q^i
        else:
            for i in range(1,N+1):
                s+=sigma(i,k-1)*i^d*q^i
        return s

# %%
#An example of G 
Gfunct(2,10,0)
# Out:
# 18*q^10 + 13*q^9 + 15*q^8 + 8*q^7 + 12*q^6 + 6*q^5 + 7*q^4 + 4*q^3 + 3*q^2 + q - 1/24

# %%
#The H_k functions
def Hfunct(k,N):
    var('q')
    if k%2==1 or k<6:
        print('must be even and at least 6')
        return
    else:
        if k==6:
            s=(1/6)*((Gfunct(2,N,2)-Gfunct(2,N,1)+Gfunct(2,N,0))-Gfunct(4,N,0))
        else:
            s=(1/24)*(-Gfunct(k-6,N,2)+Gfunct(k-4,N,2)+Gfunct(k-4,N,0)-Gfunct(k-2,N,0))
    return s

# %%
Hfunct(6,10)
# Out:
# 84*q^10 + 32*q^9 + 45*q^8 + 20*q^6 + 3*q^4 - 11/1440

# %%
Hfunct(8,10)
# Out:
# 399*q^10 + 72*q^9 + 135*q^8 + 35*q^6 + 3*q^4 + 31/120960

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [6]
    MAX_MODULUS_TO_CHECK = 13 
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_6(q) up to q^100...
#
# --- Searching for congruences for H_6(q) ---
# Found congruence for H_6: a(2n + 1) === 0 (mod 2)
# Found congruence for H_6: a(4n + 1) === 0 (mod 2)
# Found congruence for H_6: a(4n + 2) === 0 (mod 2)
# Found congruence for H_6: a(4n + 3) === 0 (mod 2)
# Found congruence for H_6: a(6n + 1) === 0 (mod 2)
# Found congruence for H_6: a(6n + 3) === 0 (mod 2)
# Found congruence for H_6: a(6n + 5) === 0 (mod 2)
# Found congruence for H_6: a(7n + 0) === 0 (mod 2)
# Found congruence for H_6: a(7n + 3) === 0 (mod 2)
# Found congruence for H_6: a(7n + 5) === 0 (mod 2)
# Found congruence for H_6: a(7n + 6) === 0 (mod 2)
# Found congruence for H_6: a(8n + 1) === 0 (mod 2)
# Found congruence for H_6: a(8n + 2) === 0 (mod 2)
# Found congruence for H_6: a(8n + 3) === 0 (mod 2)
# Found congruence for H_6: a(8n + 5) === 0 (mod 2)
# Found congruence for H_6: a(8n + 6) === 0 (mod 2)
# Found congruence for H_6: a(8n + 7) === 0 (mod 2)
# Found congruence for H_6: a(9n + 2) === 0 (mod 2)
# Found congruence for H_6: a(9n + 3) === 0 (mod 2)
# Found congruence for H_6: a(9n + 6) === 0 (mod 2)
# Found congruence for H_6: a(10n + 1) === 0 (mod 2)
# Found congruence for H_6: a(10n + 3) === 0 (mod 2)
# Found congruence for H_6: a(10n + 5) === 0 (mod 2)
# Found congruence for H_6: a(10n + 7) === 0 (mod 2)
# Found congruence for H_6: a(10n + 9) === 0 (mod 2)
# Found congruence for H_6: a(11n + 0) === 0 (mod 2)
# Found congruence for H_6: a(11n + 2) === 0 (mod 2)
# Found congruence for H_6: a(11n + 7) === 0 (mod 2)
# Found congruence for H_6: a(12n + 1) === 0 (mod 2)
# Found congruence for H_6: a(12n + 2) === 0 (mod 2)
# Found congruence for H_6: a(12n + 3) === 0 (mod 2)
# Found congruence for H_6: a(12n + 5) === 0 (mod 2)
# Found congruence for H_6: a(12n + 6) === 0 (mod 2)
# Found congruence for H_6: a(12n + 7) === 0 (mod 2)
# Found congruence for H_6: a(12n + 9) === 0 (mod 2)
# Found congruence for H_6: a(12n + 10) === 0 (mod 2)
# Found congruence for H_6: a(12n + 11) === 0 (mod 2)
# Found congruence for H_6: a(3n + 1) === 0 (mod 3)
# Found congruence for H_6: a(3n + 2) === 0 (mod 3)
# Found congruence for H_6: a(6n + 1) === 0 (mod 3)
# Found congruence for H_6: a(6n + 2) === 0 (mod 3)
# Found congruence for H_6: a(6n + 4) === 0 (mod 3)
# Found congruence for H_6: a(6n + 5) === 0 (mod 3)
# Found congruence for H_6: a(9n + 1) === 0 (mod 3)
# Found congruence for H_6: a(9n + 2) === 0 (mod 3)
# Found congruence for H_6: a(9n + 4) === 0 (mod 3)
# Found congruence for H_6: a(9n + 5) === 0 (mod 3)
# Found congruence for H_6: a(9n + 7) === 0 (mod 3)
# Found congruence for H_6: a(9n + 8) === 0 (mod 3)
# Found congruence for H_6: a(12n + 1) === 0 (mod 3)
# Found congruence for H_6: a(12n + 2) === 0 (mod 3)
# Found congruence for H_6: a(12n + 4) === 0 (mod 3)
# Found congruence for H_6: a(12n + 5) === 0 (mod 3)
# Found congruence for H_6: a(12n + 7) === 0 (mod 3)
# Found congruence for H_6: a(12n + 8) === 0 (mod 3)
# Found congruence for H_6: a(12n + 10) === 0 (mod 3)
# Found congruence for H_6: a(12n + 11) === 0 (mod 3)
# Found congruence for H_6: a(2n + 1) === 0 (mod 4)
# Found congruence for H_6: a(4n + 1) === 0 (mod 4)
# Found congruence for H_6: a(4n + 2) === 0 (mod 4)
# Found congruence for H_6: a(4n + 3) === 0 (mod 4)
# Found congruence for H_6: a(6n + 1) === 0 (mod 4)
# Found congruence for H_6: a(6n + 3) === 0 (mod 4)
# Found congruence for H_6: a(6n + 5) === 0 (mod 4)
# Found congruence for H_6: a(7n + 0) === 0 (mod 4)
# Found congruence for H_6: a(8n + 1) === 0 (mod 4)
# Found congruence for H_6: a(8n + 2) === 0 (mod 4)
# Found congruence for H_6: a(8n + 3) === 0 (mod 4)
# Found congruence for H_6: a(8n + 5) === 0 (mod 4)
# Found congruence for H_6: a(8n + 6) === 0 (mod 4)
# Found congruence for H_6: a(8n + 7) === 0 (mod 4)
# Found congruence for H_6: a(9n + 3) === 0 (mod 4)
# Found congruence for H_6: a(9n + 6) === 0 (mod 4)
# Found congruence for H_6: a(10n + 1) === 0 (mod 4)
# Found congruence for H_6: a(10n + 3) === 0 (mod 4)
# Found congruence for H_6: a(10n + 5) === 0 (mod 4)
# Found congruence for H_6: a(10n + 7) === 0 (mod 4)
# Found congruence for H_6: a(10n + 9) === 0 (mod 4)
# Found congruence for H_6: a(11n + 0) === 0 (mod 4)
# Found congruence for H_6: a(12n + 1) === 0 (mod 4)
# Found congruence for H_6: a(12n + 2) === 0 (mod 4)
# Found congruence for H_6: a(12n + 3) === 0 (mod 4)
# Found congruence for H_6: a(12n + 5) === 0 (mod 4)
# Found congruence for H_6: a(12n + 6) === 0 (mod 4)
# Found congruence for H_6: a(12n + 7) === 0 (mod 4)
# Found congruence for H_6: a(12n + 9) === 0 (mod 4)
# Found congruence for H_6: a(12n + 10) === 0 (mod 4)
# Found congruence for H_6: a(12n + 11) === 0 (mod 4)
# Found congruence for H_6: a(5n + 1) === 0 (mod 5)
# Found congruence for H_6: a(5n + 2) === 0 (mod 5)
# Found congruence for H_6: a(5n + 3) === 0 (mod 5)
# Found congruence for H_6: a(10n + 1) === 0 (mod 5)
# Found congruence for H_6: a(10n + 2) === 0 (mod 5)
# Found congruence for H_6: a(10n + 3) === 0 (mod 5)
# Found congruence for H_6: a(10n + 6) === 0 (mod 5)
# Found congruence for H_6: a(10n + 7) === 0 (mod 5)
# Found congruence for H_6: a(10n + 8) === 0 (mod 5)
# Found congruence for H_6: a(12n + 7) === 0 (mod 5)
# Found congruence for H_6: a(6n + 1) === 0 (mod 6)
# Found congruence for H_6: a(6n + 5) === 0 (mod 6)
# Found congruence for H_6: a(9n + 2) === 0 (mod 6)
# Found congruence for H_6: a(12n + 1) === 0 (mod 6)
# Found congruence for H_6: a(12n + 2) === 0 (mod 6)
# Found congruence for H_6: a(12n + 5) === 0 (mod 6)
# Found congruence for H_6: a(12n + 7) === 0 (mod 6)
# Found congruence for H_6: a(12n + 10) === 0 (mod 6)
# Found congruence for H_6: a(12n + 11) === 0 (mod 6)
# Found congruence for H_6: a(7n + 3) === 0 (mod 7)
# Found congruence for H_6: a(7n + 5) === 0 (mod 7)
# Found congruence for H_6: a(2n + 1) === 0 (mod 8)
# Found congruence for H_6: a(4n + 1) === 0 (mod 8)
# Found congruence for H_6: a(4n + 3) === 0 (mod 8)
# Found congruence for H_6: a(6n + 1) === 0 (mod 8)
# Found congruence for H_6: a(6n + 3) === 0 (mod 8)
# Found congruence for H_6: a(6n + 5) === 0 (mod 8)
# Found congruence for H_6: a(7n + 0) === 0 (mod 8)
# Found congruence for H_6: a(8n + 1) === 0 (mod 8)
# Found congruence for H_6: a(8n + 3) === 0 (mod 8)
# Found congruence for H_6: a(8n + 5) === 0 (mod 8)
# Found congruence for H_6: a(8n + 7) === 0 (mod 8)
# Found congruence for H_6: a(9n + 3) === 0 (mod 8)
# Found congruence for H_6: a(10n + 1) === 0 (mod 8)
# Found congruence for H_6: a(10n + 3) === 0 (mod 8)
# Found congruence for H_6: a(10n + 5) === 0 (mod 8)
# Found congruence for H_6: a(10n + 7) === 0 (mod 8)
# Found congruence for H_6: a(10n + 9) === 0 (mod 8)
# Found congruence for H_6: a(12n + 1) === 0 (mod 8)
# Found congruence for H_6: a(12n + 3) === 0 (mod 8)
# Found congruence for H_6: a(12n + 5) === 0 (mod 8)
# Found congruence for H_6: a(12n + 7) === 0 (mod 8)
# Found congruence for H_6: a(12n + 9) === 0 (mod 8)
# Found congruence for H_6: a(12n + 11) === 0 (mod 8)
# Found congruence for H_6: a(3n + 2) === 0 (mod 9)
# Found congruence for H_6: a(6n + 2) === 0 (mod 9)
# Found congruence for H_6: a(6n + 5) === 0 (mod 9)
# Found congruence for H_6: a(9n + 2) === 0 (mod 9)
# Found congruence for H_6: a(9n + 5) === 0 (mod 9)
# Found congruence for H_6: a(9n + 8) === 0 (mod 9)
# Found congruence for H_6: a(12n + 2) === 0 (mod 9)
# Found congruence for H_6: a(12n + 5) === 0 (mod 9)
# Found congruence for H_6: a(12n + 8) === 0 (mod 9)
# Found congruence for H_6: a(12n + 11) === 0 (mod 9)
# Found congruence for H_6: a(10n + 1) === 0 (mod 10)
# Found congruence for H_6: a(10n + 3) === 0 (mod 10)
# Found congruence for H_6: a(10n + 7) === 0 (mod 10)
# Found congruence for H_6: a(12n + 7) === 0 (mod 10)
# Found congruence for H_6: a(6n + 1) === 0 (mod 12)
# Found congruence for H_6: a(6n + 5) === 0 (mod 12)
# Found congruence for H_6: a(12n + 1) === 0 (mod 12)
# Found congruence for H_6: a(12n + 2) === 0 (mod 12)
# Found congruence for H_6: a(12n + 5) === 0 (mod 12)
# Found congruence for H_6: a(12n + 7) === 0 (mod 12)
# Found congruence for H_6: a(12n + 10) === 0 (mod 12)
# Found congruence for H_6: a(12n + 11) === 0 (mod 12)

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [8]
    MAX_MODULUS_TO_CHECK = 13 
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_8(q) up to q^100...
#
# --- Searching for congruences for H_8(q) ---
# Found congruence for H_8: a(2n + 1) === 0 (mod 2)
# Found congruence for H_8: a(4n + 1) === 0 (mod 2)
# Found congruence for H_8: a(4n + 3) === 0 (mod 2)
# Found congruence for H_8: a(6n + 1) === 0 (mod 2)
# Found congruence for H_8: a(6n + 3) === 0 (mod 2)
# Found congruence for H_8: a(6n + 5) === 0 (mod 2)
# Found congruence for H_8: a(7n + 0) === 0 (mod 2)
# Found congruence for H_8: a(8n + 1) === 0 (mod 2)
# Found congruence for H_8: a(8n + 3) === 0 (mod 2)
# Found congruence for H_8: a(8n + 5) === 0 (mod 2)
# Found congruence for H_8: a(8n + 7) === 0 (mod 2)
# Found congruence for H_8: a(10n + 1) === 0 (mod 2)
# Found congruence for H_8: a(10n + 3) === 0 (mod 2)
# Found congruence for H_8: a(10n + 5) === 0 (mod 2)
# Found congruence for H_8: a(10n + 7) === 0 (mod 2)
# Found congruence for H_8: a(10n + 9) === 0 (mod 2)
# Found congruence for H_8: a(12n + 1) === 0 (mod 2)
# Found congruence for H_8: a(12n + 3) === 0 (mod 2)
# Found congruence for H_8: a(12n + 5) === 0 (mod 2)
# Found congruence for H_8: a(12n + 7) === 0 (mod 2)
# Found congruence for H_8: a(12n + 9) === 0 (mod 2)
# Found congruence for H_8: a(12n + 11) === 0 (mod 2)
# Found congruence for H_8: a(3n + 1) === 0 (mod 3)
# Found congruence for H_8: a(3n + 2) === 0 (mod 3)
# Found congruence for H_8: a(6n + 1) === 0 (mod 3)
# Found congruence for H_8: a(6n + 2) === 0 (mod 3)
# Found congruence for H_8: a(6n + 4) === 0 (mod 3)
# Found congruence for H_8: a(6n + 5) === 0 (mod 3)
# Found congruence for H_8: a(9n + 1) === 0 (mod 3)
# Found congruence for H_8: a(9n + 2) === 0 (mod 3)
# Found congruence for H_8: a(9n + 4) === 0 (mod 3)
# Found congruence for H_8: a(9n + 5) === 0 (mod 3)
# Found congruence for H_8: a(9n + 7) === 0 (mod 3)
# Found congruence for H_8: a(9n + 8) === 0 (mod 3)
# Found congruence for H_8: a(12n + 1) === 0 (mod 3)
# Found congruence for H_8: a(12n + 2) === 0 (mod 3)
# Found congruence for H_8: a(12n + 4) === 0 (mod 3)
# Found congruence for H_8: a(12n + 5) === 0 (mod 3)
# Found congruence for H_8: a(12n + 7) === 0 (mod 3)
# Found congruence for H_8: a(12n + 8) === 0 (mod 3)
# Found congruence for H_8: a(12n + 10) === 0 (mod 3)
# Found congruence for H_8: a(12n + 11) === 0 (mod 3)
# Found congruence for H_8: a(2n + 1) === 0 (mod 4)
# Found congruence for H_8: a(4n + 1) === 0 (mod 4)
# Found congruence for H_8: a(4n + 3) === 0 (mod 4)
# Found congruence for H_8: a(6n + 1) === 0 (mod 4)
# Found congruence for H_8: a(6n + 3) === 0 (mod 4)
# Found congruence for H_8: a(6n + 5) === 0 (mod 4)
# Found congruence for H_8: a(8n + 1) === 0 (mod 4)
# Found congruence for H_8: a(8n + 3) === 0 (mod 4)
# Found congruence for H_8: a(8n + 5) === 0 (mod 4)
# Found congruence for H_8: a(8n + 7) === 0 (mod 4)
# Found congruence for H_8: a(10n + 1) === 0 (mod 4)
# Found congruence for H_8: a(10n + 3) === 0 (mod 4)
# Found congruence for H_8: a(10n + 5) === 0 (mod 4)
# Found congruence for H_8: a(10n + 7) === 0 (mod 4)
# Found congruence for H_8: a(10n + 9) === 0 (mod 4)
# Found congruence for H_8: a(12n + 1) === 0 (mod 4)
# Found congruence for H_8: a(12n + 3) === 0 (mod 4)
# Found congruence for H_8: a(12n + 5) === 0 (mod 4)
# Found congruence for H_8: a(12n + 7) === 0 (mod 4)
# Found congruence for H_8: a(12n + 9) === 0 (mod 4)
# Found congruence for H_8: a(12n + 11) === 0 (mod 4)
# Found congruence for H_8: a(5n + 1) === 0 (mod 5)
# Found congruence for H_8: a(5n + 2) === 0 (mod 5)
# Found congruence for H_8: a(5n + 3) === 0 (mod 5)
# Found congruence for H_8: a(10n + 1) === 0 (mod 5)
# Found congruence for H_8: a(10n + 2) === 0 (mod 5)
# Found congruence for H_8: a(10n + 3) === 0 (mod 5)
# Found congruence for H_8: a(10n + 6) === 0 (mod 5)
# Found congruence for H_8: a(10n + 7) === 0 (mod 5)
# Found congruence for H_8: a(10n + 8) === 0 (mod 5)
# Found congruence for H_8: a(12n + 7) === 0 (mod 5)
# Found congruence for H_8: a(6n + 1) === 0 (mod 6)
# Found congruence for H_8: a(6n + 5) === 0 (mod 6)
# Found congruence for H_8: a(12n + 1) === 0 (mod 6)
# Found congruence for H_8: a(12n + 5) === 0 (mod 6)
# Found congruence for H_8: a(12n + 7) === 0 (mod 6)
# Found congruence for H_8: a(12n + 11) === 0 (mod 6)
# Found congruence for H_8: a(7n + 3) === 0 (mod 7)
# Found congruence for H_8: a(7n + 5) === 0 (mod 7)
# Found congruence for H_8: a(7n + 6) === 0 (mod 7)
# Found congruence for H_8: a(12n + 7) === 0 (mod 7)
# Found congruence for H_8: a(2n + 1) === 0 (mod 8)
# Found congruence for H_8: a(4n + 1) === 0 (mod 8)
# Found congruence for H_8: a(4n + 3) === 0 (mod 8)
# Found congruence for H_8: a(6n + 1) === 0 (mod 8)
# Found congruence for H_8: a(6n + 3) === 0 (mod 8)
# Found congruence for H_8: a(6n + 5) === 0 (mod 8)
# Found congruence for H_8: a(8n + 1) === 0 (mod 8)
# Found congruence for H_8: a(8n + 3) === 0 (mod 8)
# Found congruence for H_8: a(8n + 5) === 0 (mod 8)
# Found congruence for H_8: a(8n + 7) === 0 (mod 8)
# Found congruence for H_8: a(10n + 1) === 0 (mod 8)
# Found congruence for H_8: a(10n + 3) === 0 (mod 8)
# Found congruence for H_8: a(10n + 5) === 0 (mod 8)
# Found congruence for H_8: a(10n + 7) === 0 (mod 8)
# Found congruence for H_8: a(10n + 9) === 0 (mod 8)
# Found congruence for H_8: a(12n + 1) === 0 (mod 8)
# Found congruence for H_8: a(12n + 3) === 0 (mod 8)
# Found congruence for H_8: a(12n + 5) === 0 (mod 8)
# Found congruence for H_8: a(12n + 7) === 0 (mod 8)
# Found congruence for H_8: a(12n + 9) === 0 (mod 8)
# Found congruence for H_8: a(12n + 11) === 0 (mod 8)
# Found congruence for H_8: a(3n + 2) === 0 (mod 9)
# Found congruence for H_8: a(6n + 2) === 0 (mod 9)
# Found congruence for H_8: a(6n + 5) === 0 (mod 9)
# Found congruence for H_8: a(9n + 2) === 0 (mod 9)
# Found congruence for H_8: a(9n + 5) === 0 (mod 9)
# Found congruence for H_8: a(9n + 8) === 0 (mod 9)
# Found congruence for H_8: a(12n + 2) === 0 (mod 9)
# Found congruence for H_8: a(12n + 5) === 0 (mod 9)
# Found congruence for H_8: a(12n + 8) === 0 (mod 9)
# Found congruence for H_8: a(12n + 11) === 0 (mod 9)
# Found congruence for H_8: a(10n + 1) === 0 (mod 10)
# Found congruence for H_8: a(10n + 3) === 0 (mod 10)
# Found congruence for H_8: a(10n + 7) === 0 (mod 10)
# Found congruence for H_8: a(12n + 7) === 0 (mod 10)
# Found congruence for H_8: a(6n + 1) === 0 (mod 12)
# Found congruence for H_8: a(6n + 5) === 0 (mod 12)
# Found congruence for H_8: a(12n + 1) === 0 (mod 12)
# Found congruence for H_8: a(12n + 5) === 0 (mod 12)
# Found congruence for H_8: a(12n + 7) === 0 (mod 12)
# Found congruence for H_8: a(12n + 11) === 0 (mod 12)

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [10]
    MAX_MODULUS_TO_CHECK = 12
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_10(q) up to q^100...
#
# --- Searching for congruences for H_10(q) ---
# Found congruence for H_10: a(2n + 1) === 0 (mod 2)
# Found congruence for H_10: a(4n + 1) === 0 (mod 2)
# Found congruence for H_10: a(4n + 3) === 0 (mod 2)
# Found congruence for H_10: a(6n + 1) === 0 (mod 2)
# Found congruence for H_10: a(6n + 3) === 0 (mod 2)
# Found congruence for H_10: a(6n + 5) === 0 (mod 2)
# Found congruence for H_10: a(7n + 0) === 0 (mod 2)
# Found congruence for H_10: a(8n + 1) === 0 (mod 2)
# Found congruence for H_10: a(8n + 3) === 0 (mod 2)
# Found congruence for H_10: a(8n + 5) === 0 (mod 2)
# Found congruence for H_10: a(8n + 7) === 0 (mod 2)
# Found congruence for H_10: a(10n + 1) === 0 (mod 2)
# Found congruence for H_10: a(10n + 3) === 0 (mod 2)
# Found congruence for H_10: a(10n + 5) === 0 (mod 2)
# Found congruence for H_10: a(10n + 7) === 0 (mod 2)
# Found congruence for H_10: a(10n + 9) === 0 (mod 2)
# Found congruence for H_10: a(12n + 1) === 0 (mod 2)
# Found congruence for H_10: a(12n + 3) === 0 (mod 2)
# Found congruence for H_10: a(12n + 5) === 0 (mod 2)
# Found congruence for H_10: a(12n + 7) === 0 (mod 2)
# Found congruence for H_10: a(12n + 9) === 0 (mod 2)
# Found congruence for H_10: a(12n + 11) === 0 (mod 2)
# Found congruence for H_10: a(3n + 1) === 0 (mod 3)
# Found congruence for H_10: a(3n + 2) === 0 (mod 3)
# Found congruence for H_10: a(6n + 1) === 0 (mod 3)
# Found congruence for H_10: a(6n + 2) === 0 (mod 3)
# Found congruence for H_10: a(6n + 4) === 0 (mod 3)
# Found congruence for H_10: a(6n + 5) === 0 (mod 3)
# Found congruence for H_10: a(9n + 1) === 0 (mod 3)
# Found congruence for H_10: a(9n + 2) === 0 (mod 3)
# Found congruence for H_10: a(9n + 4) === 0 (mod 3)
# Found congruence for H_10: a(9n + 5) === 0 (mod 3)
# Found congruence for H_10: a(9n + 7) === 0 (mod 3)
# Found congruence for H_10: a(9n + 8) === 0 (mod 3)
# Found congruence for H_10: a(12n + 1) === 0 (mod 3)
# Found congruence for H_10: a(12n + 2) === 0 (mod 3)
# Found congruence for H_10: a(12n + 4) === 0 (mod 3)
# Found congruence for H_10: a(12n + 5) === 0 (mod 3)
# Found congruence for H_10: a(12n + 7) === 0 (mod 3)
# Found congruence for H_10: a(12n + 8) === 0 (mod 3)
# Found congruence for H_10: a(12n + 10) === 0 (mod 3)
# Found congruence for H_10: a(12n + 11) === 0 (mod 3)
# Found congruence for H_10: a(2n + 1) === 0 (mod 4)
# Found congruence for H_10: a(4n + 1) === 0 (mod 4)
# Found congruence for H_10: a(4n + 3) === 0 (mod 4)
# Found congruence for H_10: a(6n + 1) === 0 (mod 4)
# Found congruence for H_10: a(6n + 3) === 0 (mod 4)
# Found congruence for H_10: a(6n + 5) === 0 (mod 4)
# Found congruence for H_10: a(8n + 1) === 0 (mod 4)
# Found congruence for H_10: a(8n + 3) === 0 (mod 4)
# Found congruence for H_10: a(8n + 5) === 0 (mod 4)
# Found congruence for H_10: a(8n + 7) === 0 (mod 4)
# Found congruence for H_10: a(10n + 1) === 0 (mod 4)
# Found congruence for H_10: a(10n + 3) === 0 (mod 4)
# Found congruence for H_10: a(10n + 5) === 0 (mod 4)
# Found congruence for H_10: a(10n + 7) === 0 (mod 4)
# Found congruence for H_10: a(10n + 9) === 0 (mod 4)
# Found congruence for H_10: a(12n + 1) === 0 (mod 4)
# Found congruence for H_10: a(12n + 3) === 0 (mod 4)
# Found congruence for H_10: a(12n + 5) === 0 (mod 4)
# Found congruence for H_10: a(12n + 7) === 0 (mod 4)
# Found congruence for H_10: a(12n + 9) === 0 (mod 4)
# Found congruence for H_10: a(12n + 11) === 0 (mod 4)
# Found congruence for H_10: a(5n + 1) === 0 (mod 5)
# Found congruence for H_10: a(5n + 2) === 0 (mod 5)
# Found congruence for H_10: a(5n + 3) === 0 (mod 5)
# Found congruence for H_10: a(10n + 1) === 0 (mod 5)
# Found congruence for H_10: a(10n + 2) === 0 (mod 5)
# Found congruence for H_10: a(10n + 3) === 0 (mod 5)
# Found congruence for H_10: a(10n + 6) === 0 (mod 5)
# Found congruence for H_10: a(10n + 7) === 0 (mod 5)
# Found congruence for H_10: a(10n + 8) === 0 (mod 5)
# Found congruence for H_10: a(12n + 7) === 0 (mod 5)
# Found congruence for H_10: a(6n + 1) === 0 (mod 6)
# Found congruence for H_10: a(6n + 5) === 0 (mod 6)
# Found congruence for H_10: a(12n + 1) === 0 (mod 6)
# Found congruence for H_10: a(12n + 5) === 0 (mod 6)
# Found congruence for H_10: a(12n + 7) === 0 (mod 6)
# Found congruence for H_10: a(12n + 11) === 0 (mod 6)
# Found congruence for H_10: a(7n + 3) === 0 (mod 7)
# Found congruence for H_10: a(7n + 5) === 0 (mod 7)
# Found congruence for H_10: a(2n + 1) === 0 (mod 8)
# Found congruence for H_10: a(4n + 1) === 0 (mod 8)
# Found congruence for H_10: a(4n + 3) === 0 (mod 8)
# Found congruence for H_10: a(6n + 1) === 0 (mod 8)
# Found congruence for H_10: a(6n + 3) === 0 (mod 8)
# Found congruence for H_10: a(6n + 5) === 0 (mod 8)
# Found congruence for H_10: a(8n + 1) === 0 (mod 8)
# Found congruence for H_10: a(8n + 3) === 0 (mod 8)
# Found congruence for H_10: a(8n + 5) === 0 (mod 8)
# Found congruence for H_10: a(8n + 7) === 0 (mod 8)
# Found congruence for H_10: a(10n + 1) === 0 (mod 8)
# Found congruence for H_10: a(10n + 3) === 0 (mod 8)
# Found congruence for H_10: a(10n + 5) === 0 (mod 8)
# Found congruence for H_10: a(10n + 7) === 0 (mod 8)
# Found congruence for H_10: a(10n + 9) === 0 (mod 8)
# Found congruence for H_10: a(12n + 1) === 0 (mod 8)
# Found congruence for H_10: a(12n + 3) === 0 (mod 8)
# Found congruence for H_10: a(12n + 5) === 0 (mod 8)
# Found congruence for H_10: a(12n + 7) === 0 (mod 8)
# Found congruence for H_10: a(12n + 9) === 0 (mod 8)
# Found congruence for H_10: a(12n + 11) === 0 (mod 8)
# Found congruence for H_10: a(3n + 2) === 0 (mod 9)
# Found congruence for H_10: a(6n + 2) === 0 (mod 9)
# Found congruence for H_10: a(6n + 5) === 0 (mod 9)
# Found congruence for H_10: a(9n + 2) === 0 (mod 9)
# Found congruence for H_10: a(9n + 5) === 0 (mod 9)
# Found congruence for H_10: a(9n + 8) === 0 (mod 9)
# Found congruence for H_10: a(12n + 2) === 0 (mod 9)
# Found congruence for H_10: a(12n + 5) === 0 (mod 9)
# Found congruence for H_10: a(12n + 8) === 0 (mod 9)
# Found congruence for H_10: a(12n + 11) === 0 (mod 9)
# Found congruence for H_10: a(10n + 1) === 0 (mod 10)
# Found congruence for H_10: a(10n + 3) === 0 (mod 10)
# Found congruence for H_10: a(10n + 7) === 0 (mod 10)
# Found congruence for H_10: a(12n + 7) === 0 (mod 10)
# Found congruence for H_10: a(11n + 2) === 0 (mod 11)
# Found congruence for H_10: a(11n + 6) === 0 (mod 11)
# Found congruence for H_10: a(11n + 7) === 0 (mod 11)
# Found congruence for H_10: a(11n + 8) === 0 (mod 11)
# Found congruence for H_10: a(11n + 10) === 0 (mod 11)
# Found congruence for H_10: a(12n + 11) === 0 (mod 11)
# Found congruence for H_10: a(6n + 1) === 0 (mod 12)
# Found congruence for H_10: a(6n + 5) === 0 (mod 12)
# Found congruence for H_10: a(12n + 1) === 0 (mod 12)
# Found congruence for H_10: a(12n + 5) === 0 (mod 12)
# Found congruence for H_10: a(12n + 7) === 0 (mod 12)
# Found congruence for H_10: a(12n + 11) === 0 (mod 12)

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [12]
    MAX_MODULUS_TO_CHECK = 12 
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_12(q) up to q^100...
#
# --- Searching for congruences for H_12(q) ---
# Found congruence for H_12: a(2n + 1) === 0 (mod 2)
# Found congruence for H_12: a(4n + 1) === 0 (mod 2)
# Found congruence for H_12: a(4n + 3) === 0 (mod 2)
# Found congruence for H_12: a(6n + 1) === 0 (mod 2)
# Found congruence for H_12: a(6n + 3) === 0 (mod 2)
# Found congruence for H_12: a(6n + 5) === 0 (mod 2)
# Found congruence for H_12: a(7n + 0) === 0 (mod 2)
# Found congruence for H_12: a(8n + 1) === 0 (mod 2)
# Found congruence for H_12: a(8n + 3) === 0 (mod 2)
# Found congruence for H_12: a(8n + 5) === 0 (mod 2)
# Found congruence for H_12: a(8n + 7) === 0 (mod 2)
# Found congruence for H_12: a(10n + 1) === 0 (mod 2)
# Found congruence for H_12: a(10n + 3) === 0 (mod 2)
# Found congruence for H_12: a(10n + 5) === 0 (mod 2)
# Found congruence for H_12: a(10n + 7) === 0 (mod 2)
# Found congruence for H_12: a(10n + 9) === 0 (mod 2)
# Found congruence for H_12: a(12n + 1) === 0 (mod 2)
# Found congruence for H_12: a(12n + 3) === 0 (mod 2)
# Found congruence for H_12: a(12n + 5) === 0 (mod 2)
# Found congruence for H_12: a(12n + 7) === 0 (mod 2)
# Found congruence for H_12: a(12n + 9) === 0 (mod 2)
# Found congruence for H_12: a(12n + 11) === 0 (mod 2)
# Found congruence for H_12: a(3n + 1) === 0 (mod 3)
# Found congruence for H_12: a(3n + 2) === 0 (mod 3)
# Found congruence for H_12: a(6n + 1) === 0 (mod 3)
# Found congruence for H_12: a(6n + 2) === 0 (mod 3)
# Found congruence for H_12: a(6n + 4) === 0 (mod 3)
# Found congruence for H_12: a(6n + 5) === 0 (mod 3)
# Found congruence for H_12: a(9n + 1) === 0 (mod 3)
# Found congruence for H_12: a(9n + 2) === 0 (mod 3)
# Found congruence for H_12: a(9n + 4) === 0 (mod 3)
# Found congruence for H_12: a(9n + 5) === 0 (mod 3)
# Found congruence for H_12: a(9n + 7) === 0 (mod 3)
# Found congruence for H_12: a(9n + 8) === 0 (mod 3)
# Found congruence for H_12: a(12n + 1) === 0 (mod 3)
# Found congruence for H_12: a(12n + 2) === 0 (mod 3)
# Found congruence for H_12: a(12n + 4) === 0 (mod 3)
# Found congruence for H_12: a(12n + 5) === 0 (mod 3)
# Found congruence for H_12: a(12n + 7) === 0 (mod 3)
# Found congruence for H_12: a(12n + 8) === 0 (mod 3)
# Found congruence for H_12: a(12n + 10) === 0 (mod 3)
# Found congruence for H_12: a(12n + 11) === 0 (mod 3)
# Found congruence for H_12: a(2n + 1) === 0 (mod 4)
# Found congruence for H_12: a(4n + 1) === 0 (mod 4)
# Found congruence for H_12: a(4n + 3) === 0 (mod 4)
# Found congruence for H_12: a(6n + 1) === 0 (mod 4)
# Found congruence for H_12: a(6n + 3) === 0 (mod 4)
# Found congruence for H_12: a(6n + 5) === 0 (mod 4)
# Found congruence for H_12: a(8n + 1) === 0 (mod 4)
# Found congruence for H_12: a(8n + 3) === 0 (mod 4)
# Found congruence for H_12: a(8n + 5) === 0 (mod 4)
# Found congruence for H_12: a(8n + 7) === 0 (mod 4)
# Found congruence for H_12: a(10n + 1) === 0 (mod 4)
# Found congruence for H_12: a(10n + 3) === 0 (mod 4)
# Found congruence for H_12: a(10n + 5) === 0 (mod 4)
# Found congruence for H_12: a(10n + 7) === 0 (mod 4)
# Found congruence for H_12: a(10n + 9) === 0 (mod 4)
# Found congruence for H_12: a(12n + 1) === 0 (mod 4)
# Found congruence for H_12: a(12n + 3) === 0 (mod 4)
# Found congruence for H_12: a(12n + 5) === 0 (mod 4)
# Found congruence for H_12: a(12n + 7) === 0 (mod 4)
# Found congruence for H_12: a(12n + 9) === 0 (mod 4)
# Found congruence for H_12: a(12n + 11) === 0 (mod 4)
# Found congruence for H_12: a(5n + 1) === 0 (mod 5)
# Found congruence for H_12: a(5n + 2) === 0 (mod 5)
# Found congruence for H_12: a(5n + 3) === 0 (mod 5)
# Found congruence for H_12: a(10n + 1) === 0 (mod 5)
# Found congruence for H_12: a(10n + 2) === 0 (mod 5)
# Found congruence for H_12: a(10n + 3) === 0 (mod 5)
# Found congruence for H_12: a(10n + 6) === 0 (mod 5)
# Found congruence for H_12: a(10n + 7) === 0 (mod 5)
# Found congruence for H_12: a(10n + 8) === 0 (mod 5)
# Found congruence for H_12: a(12n + 7) === 0 (mod 5)
# Found congruence for H_12: a(6n + 1) === 0 (mod 6)
# Found congruence for H_12: a(6n + 5) === 0 (mod 6)
# Found congruence for H_12: a(12n + 1) === 0 (mod 6)
# Found congruence for H_12: a(12n + 5) === 0 (mod 6)
# Found congruence for H_12: a(12n + 7) === 0 (mod 6)
# Found congruence for H_12: a(12n + 11) === 0 (mod 6)
# Found congruence for H_12: a(7n + 3) === 0 (mod 7)
# Found congruence for H_12: a(7n + 5) === 0 (mod 7)
# Found congruence for H_12: a(2n + 1) === 0 (mod 8)
# Found congruence for H_12: a(4n + 1) === 0 (mod 8)
# Found congruence for H_12: a(4n + 3) === 0 (mod 8)
# Found congruence for H_12: a(6n + 1) === 0 (mod 8)
# Found congruence for H_12: a(6n + 3) === 0 (mod 8)
# Found congruence for H_12: a(6n + 5) === 0 (mod 8)
# Found congruence for H_12: a(8n + 1) === 0 (mod 8)
# Found congruence for H_12: a(8n + 3) === 0 (mod 8)
# Found congruence for H_12: a(8n + 5) === 0 (mod 8)
# Found congruence for H_12: a(8n + 7) === 0 (mod 8)
# Found congruence for H_12: a(10n + 1) === 0 (mod 8)
# Found congruence for H_12: a(10n + 3) === 0 (mod 8)
# Found congruence for H_12: a(10n + 5) === 0 (mod 8)
# Found congruence for H_12: a(10n + 7) === 0 (mod 8)
# Found congruence for H_12: a(10n + 9) === 0 (mod 8)
# Found congruence for H_12: a(12n + 1) === 0 (mod 8)
# Found congruence for H_12: a(12n + 3) === 0 (mod 8)
# Found congruence for H_12: a(12n + 5) === 0 (mod 8)
# Found congruence for H_12: a(12n + 7) === 0 (mod 8)
# Found congruence for H_12: a(12n + 9) === 0 (mod 8)
# Found congruence for H_12: a(12n + 11) === 0 (mod 8)
# Found congruence for H_12: a(3n + 2) === 0 (mod 9)
# Found congruence for H_12: a(6n + 2) === 0 (mod 9)
# Found congruence for H_12: a(6n + 5) === 0 (mod 9)
# Found congruence for H_12: a(9n + 2) === 0 (mod 9)
# Found congruence for H_12: a(9n + 5) === 0 (mod 9)
# Found congruence for H_12: a(9n + 8) === 0 (mod 9)
# Found congruence for H_12: a(12n + 2) === 0 (mod 9)
# Found congruence for H_12: a(12n + 5) === 0 (mod 9)
# Found congruence for H_12: a(12n + 8) === 0 (mod 9)
# Found congruence for H_12: a(12n + 11) === 0 (mod 9)
# Found congruence for H_12: a(10n + 1) === 0 (mod 10)
# Found congruence for H_12: a(10n + 3) === 0 (mod 10)
# Found congruence for H_12: a(10n + 7) === 0 (mod 10)
# Found congruence for H_12: a(12n + 7) === 0 (mod 10)
# Found congruence for H_12: a(6n + 1) === 0 (mod 12)
# Found congruence for H_12: a(6n + 5) === 0 (mod 12)
# Found congruence for H_12: a(12n + 1) === 0 (mod 12)
# Found congruence for H_12: a(12n + 5) === 0 (mod 12)
# Found congruence for H_12: a(12n + 7) === 0 (mod 12)
# Found congruence for H_12: a(12n + 11) === 0 (mod 12)

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [14]
    MAX_MODULUS_TO_CHECK = 12 
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_14(q) up to q^100...
#
# --- Searching for congruences for H_14(q) ---
# Found congruence for H_14: a(2n + 1) === 0 (mod 2)
# Found congruence for H_14: a(4n + 1) === 0 (mod 2)
# Found congruence for H_14: a(4n + 3) === 0 (mod 2)
# Found congruence for H_14: a(6n + 1) === 0 (mod 2)
# Found congruence for H_14: a(6n + 3) === 0 (mod 2)
# Found congruence for H_14: a(6n + 5) === 0 (mod 2)
# Found congruence for H_14: a(7n + 0) === 0 (mod 2)
# Found congruence for H_14: a(8n + 1) === 0 (mod 2)
# Found congruence for H_14: a(8n + 3) === 0 (mod 2)
# Found congruence for H_14: a(8n + 5) === 0 (mod 2)
# Found congruence for H_14: a(8n + 7) === 0 (mod 2)
# Found congruence for H_14: a(10n + 1) === 0 (mod 2)
# Found congruence for H_14: a(10n + 3) === 0 (mod 2)
# Found congruence for H_14: a(10n + 5) === 0 (mod 2)
# Found congruence for H_14: a(10n + 7) === 0 (mod 2)
# Found congruence for H_14: a(10n + 9) === 0 (mod 2)
# Found congruence for H_14: a(12n + 1) === 0 (mod 2)
# Found congruence for H_14: a(12n + 3) === 0 (mod 2)
# Found congruence for H_14: a(12n + 5) === 0 (mod 2)
# Found congruence for H_14: a(12n + 7) === 0 (mod 2)
# Found congruence for H_14: a(12n + 9) === 0 (mod 2)
# Found congruence for H_14: a(12n + 11) === 0 (mod 2)
# Found congruence for H_14: a(3n + 1) === 0 (mod 3)
# Found congruence for H_14: a(3n + 2) === 0 (mod 3)
# Found congruence for H_14: a(6n + 1) === 0 (mod 3)
# Found congruence for H_14: a(6n + 2) === 0 (mod 3)
# Found congruence for H_14: a(6n + 4) === 0 (mod 3)
# Found congruence for H_14: a(6n + 5) === 0 (mod 3)
# Found congruence for H_14: a(9n + 1) === 0 (mod 3)
# Found congruence for H_14: a(9n + 2) === 0 (mod 3)
# Found congruence for H_14: a(9n + 4) === 0 (mod 3)
# Found congruence for H_14: a(9n + 5) === 0 (mod 3)
# Found congruence for H_14: a(9n + 7) === 0 (mod 3)
# Found congruence for H_14: a(9n + 8) === 0 (mod 3)
# Found congruence for H_14: a(12n + 1) === 0 (mod 3)
# Found congruence for H_14: a(12n + 2) === 0 (mod 3)
# Found congruence for H_14: a(12n + 4) === 0 (mod 3)
# Found congruence for H_14: a(12n + 5) === 0 (mod 3)
# Found congruence for H_14: a(12n + 7) === 0 (mod 3)
# Found congruence for H_14: a(12n + 8) === 0 (mod 3)
# Found congruence for H_14: a(12n + 10) === 0 (mod 3)
# Found congruence for H_14: a(12n + 11) === 0 (mod 3)
# Found congruence for H_14: a(2n + 1) === 0 (mod 4)
# Found congruence for H_14: a(4n + 1) === 0 (mod 4)
# Found congruence for H_14: a(4n + 3) === 0 (mod 4)
# Found congruence for H_14: a(6n + 1) === 0 (mod 4)
# Found congruence for H_14: a(6n + 3) === 0 (mod 4)
# Found congruence for H_14: a(6n + 5) === 0 (mod 4)
# Found congruence for H_14: a(8n + 1) === 0 (mod 4)
# Found congruence for H_14: a(8n + 3) === 0 (mod 4)
# Found congruence for H_14: a(8n + 5) === 0 (mod 4)
# Found congruence for H_14: a(8n + 7) === 0 (mod 4)
# Found congruence for H_14: a(10n + 1) === 0 (mod 4)
# Found congruence for H_14: a(10n + 3) === 0 (mod 4)
# Found congruence for H_14: a(10n + 5) === 0 (mod 4)
# Found congruence for H_14: a(10n + 7) === 0 (mod 4)
# Found congruence for H_14: a(10n + 9) === 0 (mod 4)
# Found congruence for H_14: a(12n + 1) === 0 (mod 4)
# Found congruence for H_14: a(12n + 3) === 0 (mod 4)
# Found congruence for H_14: a(12n + 5) === 0 (mod 4)
# Found congruence for H_14: a(12n + 7) === 0 (mod 4)
# Found congruence for H_14: a(12n + 9) === 0 (mod 4)
# Found congruence for H_14: a(12n + 11) === 0 (mod 4)
# Found congruence for H_14: a(5n + 1) === 0 (mod 5)
# Found congruence for H_14: a(5n + 2) === 0 (mod 5)
# Found congruence for H_14: a(5n + 3) === 0 (mod 5)
# Found congruence for H_14: a(10n + 1) === 0 (mod 5)
# Found congruence for H_14: a(10n + 2) === 0 (mod 5)
# Found congruence for H_14: a(10n + 3) === 0 (mod 5)
# Found congruence for H_14: a(10n + 6) === 0 (mod 5)
# Found congruence for H_14: a(10n + 7) === 0 (mod 5)
# Found congruence for H_14: a(10n + 8) === 0 (mod 5)
# Found congruence for H_14: a(12n + 7) === 0 (mod 5)
# Found congruence for H_14: a(6n + 1) === 0 (mod 6)
# Found congruence for H_14: a(6n + 5) === 0 (mod 6)
# Found congruence for H_14: a(12n + 1) === 0 (mod 6)
# Found congruence for H_14: a(12n + 5) === 0 (mod 6)
# Found congruence for H_14: a(12n + 7) === 0 (mod 6)
# Found congruence for H_14: a(12n + 11) === 0 (mod 6)
# Found congruence for H_14: a(7n + 3) === 0 (mod 7)
# Found congruence for H_14: a(7n + 5) === 0 (mod 7)
# Found congruence for H_14: a(7n + 6) === 0 (mod 7)
# Found congruence for H_14: a(12n + 7) === 0 (mod 7)
# Found congruence for H_14: a(2n + 1) === 0 (mod 8)
# Found congruence for H_14: a(4n + 1) === 0 (mod 8)
# Found congruence for H_14: a(4n + 3) === 0 (mod 8)
# Found congruence for H_14: a(6n + 1) === 0 (mod 8)
# Found congruence for H_14: a(6n + 3) === 0 (mod 8)
# Found congruence for H_14: a(6n + 5) === 0 (mod 8)
# Found congruence for H_14: a(8n + 1) === 0 (mod 8)
# Found congruence for H_14: a(8n + 3) === 0 (mod 8)
# Found congruence for H_14: a(8n + 5) === 0 (mod 8)
# Found congruence for H_14: a(8n + 7) === 0 (mod 8)
# Found congruence for H_14: a(10n + 1) === 0 (mod 8)
# Found congruence for H_14: a(10n + 3) === 0 (mod 8)
# Found congruence for H_14: a(10n + 5) === 0 (mod 8)
# Found congruence for H_14: a(10n + 7) === 0 (mod 8)
# Found congruence for H_14: a(10n + 9) === 0 (mod 8)
# Found congruence for H_14: a(12n + 1) === 0 (mod 8)
# Found congruence for H_14: a(12n + 3) === 0 (mod 8)
# Found congruence for H_14: a(12n + 5) === 0 (mod 8)
# Found congruence for H_14: a(12n + 7) === 0 (mod 8)
# Found congruence for H_14: a(12n + 9) === 0 (mod 8)
# Found congruence for H_14: a(12n + 11) === 0 (mod 8)
# Found congruence for H_14: a(3n + 2) === 0 (mod 9)
# Found congruence for H_14: a(6n + 2) === 0 (mod 9)
# Found congruence for H_14: a(6n + 5) === 0 (mod 9)
# Found congruence for H_14: a(9n + 2) === 0 (mod 9)
# Found congruence for H_14: a(9n + 5) === 0 (mod 9)
# Found congruence for H_14: a(9n + 8) === 0 (mod 9)
# Found congruence for H_14: a(12n + 2) === 0 (mod 9)
# Found congruence for H_14: a(12n + 5) === 0 (mod 9)
# Found congruence for H_14: a(12n + 8) === 0 (mod 9)
# Found congruence for H_14: a(12n + 11) === 0 (mod 9)
# Found congruence for H_14: a(10n + 1) === 0 (mod 10)
# Found congruence for H_14: a(10n + 3) === 0 (mod 10)
# Found congruence for H_14: a(10n + 7) === 0 (mod 10)
# Found congruence for H_14: a(12n + 7) === 0 (mod 10)
# Found congruence for H_14: a(6n + 1) === 0 (mod 12)
# Found congruence for H_14: a(6n + 5) === 0 (mod 12)
# Found congruence for H_14: a(12n + 1) === 0 (mod 12)
# Found congruence for H_14: a(12n + 5) === 0 (mod 12)
# Found congruence for H_14: a(12n + 7) === 0 (mod 12)
# Found congruence for H_14: a(12n + 11) === 0 (mod 12)

# %%
def get_coefficients(series, N):
    var('q')
    coeffs = series.list()
    coeffs += [0] * (N + 1 - len(coeffs))
    return [int(c) for c in coeffs]

def find_congruences(k_val, coeffs, max_mod, max_t):
    """
    Searches for congruences of the form a(t*n + b) === 0 (mod m).
    """
    print(f"\n--- Searching for congruences for H_{k_val}(q) ---")
    found_any = False
    
    for m in range(2, max_mod + 1):
        for t in range(1, max_t + 1):
            for b in range(t):
                is_congruence = True
                for i in range(b, len(coeffs), t):
                    if coeffs[i] % m != 0:
                        is_congruence = False
                        break
                
                if is_congruence:
                    print(f"Found congruence for H_{k_val}: a({t}n + {b}) === 0 (mod {m})")
                    found_any = True

    if not found_any:
        print(f"No congruences found for H_{k_val} within the search limits.")

if __name__ == "__main__":
    #Search Parameters
    NUM_COEFFS = 100 
    K_VALUES_TO_CHECK = [256]
    MAX_MODULUS_TO_CHECK = 12 
    MAX_T_TO_CHECK = 12      

    #Analysis for H_k functions
    for k in K_VALUES_TO_CHECK:
        print(f"Generating H_{k}(q) up to q^{NUM_COEFFS}...")
        Hk_series = Hfunct(k, NUM_COEFFS)
        
        if Hk_series != 0:
            Hk_coeffs = get_coefficients(Hk_series, NUM_COEFFS)
            find_congruences(k, Hk_coeffs, MAX_MODULUS_TO_CHECK, MAX_T_TO_CHECK)
# Out:
# Generating H_256(q) up to q^100...
#
# --- Searching for congruences for H_256(q) ---
# Found congruence for H_256: a(2n + 1) === 0 (mod 2)
# Found congruence for H_256: a(4n + 1) === 0 (mod 2)
# Found congruence for H_256: a(4n + 3) === 0 (mod 2)
# Found congruence for H_256: a(6n + 1) === 0 (mod 2)
# Found congruence for H_256: a(6n + 3) === 0 (mod 2)
# Found congruence for H_256: a(6n + 5) === 0 (mod 2)
# Found congruence for H_256: a(8n + 1) === 0 (mod 2)
# Found congruence for H_256: a(8n + 3) === 0 (mod 2)
# Found congruence for H_256: a(8n + 5) === 0 (mod 2)
# Found congruence for H_256: a(8n + 7) === 0 (mod 2)
# Found congruence for H_256: a(10n + 1) === 0 (mod 2)
# Found congruence for H_256: a(10n + 3) === 0 (mod 2)
# Found congruence for H_256: a(10n + 5) === 0 (mod 2)
# Found congruence for H_256: a(10n + 7) === 0 (mod 2)
# Found congruence for H_256: a(10n + 9) === 0 (mod 2)
# Found congruence for H_256: a(12n + 1) === 0 (mod 2)
# Found congruence for H_256: a(12n + 3) === 0 (mod 2)
# Found congruence for H_256: a(12n + 5) === 0 (mod 2)
# Found congruence for H_256: a(12n + 7) === 0 (mod 2)
# Found congruence for H_256: a(12n + 9) === 0 (mod 2)
# Found congruence for H_256: a(12n + 11) === 0 (mod 2)
# Found congruence for H_256: a(3n + 1) === 0 (mod 3)
# Found congruence for H_256: a(3n + 2) === 0 (mod 3)
# Found congruence for H_256: a(6n + 1) === 0 (mod 3)
# Found congruence for H_256: a(6n + 2) === 0 (mod 3)
# Found congruence for H_256: a(6n + 4) === 0 (mod 3)
# Found congruence for H_256: a(6n + 5) === 0 (mod 3)
# Found congruence for H_256: a(9n + 1) === 0 (mod 3)
# Found congruence for H_256: a(9n + 2) === 0 (mod 3)
# Found congruence for H_256: a(9n + 4) === 0 (mod 3)
# Found congruence for H_256: a(9n + 5) === 0 (mod 3)
# Found congruence for H_256: a(9n + 7) === 0 (mod 3)
# Found congruence for H_256: a(9n + 8) === 0 (mod 3)
# Found congruence for H_256: a(12n + 1) === 0 (mod 3)
# Found congruence for H_256: a(12n + 2) === 0 (mod 3)
# Found congruence for H_256: a(12n + 4) === 0 (mod 3)
# Found congruence for H_256: a(12n + 5) === 0 (mod 3)
# Found congruence for H_256: a(12n + 7) === 0 (mod 3)
# Found congruence for H_256: a(12n + 8) === 0 (mod 3)
# Found congruence for H_256: a(12n + 10) === 0 (mod 3)
# Found congruence for H_256: a(12n + 11) === 0 (mod 3)
# Found congruence for H_256: a(2n + 1) === 0 (mod 4)
# Found congruence for H_256: a(4n + 1) === 0 (mod 4)
# Found congruence for H_256: a(4n + 3) === 0 (mod 4)
# Found congruence for H_256: a(6n + 1) === 0 (mod 4)
# Found congruence for H_256: a(6n + 3) === 0 (mod 4)
# Found congruence for H_256: a(6n + 5) === 0 (mod 4)
# Found congruence for H_256: a(8n + 1) === 0 (mod 4)
# Found congruence for H_256: a(8n + 3) === 0 (mod 4)
# Found congruence for H_256: a(8n + 5) === 0 (mod 4)
# Found congruence for H_256: a(8n + 7) === 0 (mod 4)
# Found congruence for H_256: a(10n + 1) === 0 (mod 4)
# Found congruence for H_256: a(10n + 3) === 0 (mod 4)
# Found congruence for H_256: a(10n + 5) === 0 (mod 4)
# Found congruence for H_256: a(10n + 7) === 0 (mod 4)
# Found congruence for H_256: a(10n + 9) === 0 (mod 4)
# Found congruence for H_256: a(12n + 1) === 0 (mod 4)
# Found congruence for H_256: a(12n + 3) === 0 (mod 4)
# Found congruence for H_256: a(12n + 5) === 0 (mod 4)
# Found congruence for H_256: a(12n + 7) === 0 (mod 4)
# Found congruence for H_256: a(12n + 9) === 0 (mod 4)
# Found congruence for H_256: a(12n + 11) === 0 (mod 4)
# Found congruence for H_256: a(5n + 1) === 0 (mod 5)
# Found congruence for H_256: a(5n + 2) === 0 (mod 5)
# Found congruence for H_256: a(5n + 3) === 0 (mod 5)
# Found congruence for H_256: a(10n + 1) === 0 (mod 5)
# Found congruence for H_256: a(10n + 2) === 0 (mod 5)
# Found congruence for H_256: a(10n + 3) === 0 (mod 5)
# Found congruence for H_256: a(10n + 6) === 0 (mod 5)
# Found congruence for H_256: a(10n + 7) === 0 (mod 5)
# Found congruence for H_256: a(10n + 8) === 0 (mod 5)
# Found congruence for H_256: a(12n + 7) === 0 (mod 5)
# Found congruence for H_256: a(6n + 1) === 0 (mod 6)
# Found congruence for H_256: a(6n + 5) === 0 (mod 6)
# Found congruence for H_256: a(12n + 1) === 0 (mod 6)
# Found congruence for H_256: a(12n + 5) === 0 (mod 6)
# Found congruence for H_256: a(12n + 7) === 0 (mod 6)
# Found congruence for H_256: a(12n + 11) === 0 (mod 6)
# Found congruence for H_256: a(7n + 3) === 0 (mod 7)
# Found congruence for H_256: a(7n + 5) === 0 (mod 7)
# Found congruence for H_256: a(2n + 1) === 0 (mod 8)
# Found congruence for H_256: a(4n + 1) === 0 (mod 8)
# Found congruence for H_256: a(4n + 3) === 0 (mod 8)
# Found congruence for H_256: a(6n + 1) === 0 (mod 8)
# Found congruence for H_256: a(6n + 3) === 0 (mod 8)
# Found congruence for H_256: a(6n + 5) === 0 (mod 8)
# Found congruence for H_256: a(8n + 1) === 0 (mod 8)
# Found congruence for H_256: a(8n + 3) === 0 (mod 8)
# Found congruence for H_256: a(8n + 5) === 0 (mod 8)
# Found congruence for H_256: a(8n + 7) === 0 (mod 8)
# Found congruence for H_256: a(10n + 1) === 0 (mod 8)
# Found congruence for H_256: a(10n + 3) === 0 (mod 8)
# Found congruence for H_256: a(10n + 5) === 0 (mod 8)
# Found congruence for H_256: a(10n + 7) === 0 (mod 8)
# Found congruence for H_256: a(10n + 9) === 0 (mod 8)
# Found congruence for H_256: a(12n + 1) === 0 (mod 8)
# Found congruence for H_256: a(12n + 3) === 0 (mod 8)
# Found congruence for H_256: a(12n + 5) === 0 (mod 8)
# Found congruence for H_256: a(12n + 7) === 0 (mod 8)
# Found congruence for H_256: a(12n + 9) === 0 (mod 8)
# Found congruence for H_256: a(12n + 11) === 0 (mod 8)
# Found congruence for H_256: a(3n + 2) === 0 (mod 9)
# Found congruence for H_256: a(6n + 2) === 0 (mod 9)
# Found congruence for H_256: a(6n + 5) === 0 (mod 9)
# Found congruence for H_256: a(9n + 2) === 0 (mod 9)
# Found congruence for H_256: a(9n + 5) === 0 (mod 9)
# Found congruence for H_256: a(9n + 8) === 0 (mod 9)
# Found congruence for H_256: a(12n + 2) === 0 (mod 9)
# Found congruence for H_256: a(12n + 5) === 0 (mod 9)
# Found congruence for H_256: a(12n + 8) === 0 (mod 9)
# Found congruence for H_256: a(12n + 11) === 0 (mod 9)
# Found congruence for H_256: a(10n + 1) === 0 (mod 10)
# Found congruence for H_256: a(10n + 3) === 0 (mod 10)
# Found congruence for H_256: a(10n + 7) === 0 (mod 10)
# Found congruence for H_256: a(12n + 7) === 0 (mod 10)
# Found congruence for H_256: a(6n + 1) === 0 (mod 12)
# Found congruence for H_256: a(6n + 5) === 0 (mod 12)
# Found congruence for H_256: a(12n + 1) === 0 (mod 12)
# Found congruence for H_256: a(12n + 5) === 0 (mod 12)
# Found congruence for H_256: a(12n + 7) === 0 (mod 12)
# Found congruence for H_256: a(12n + 11) === 0 (mod 12)
